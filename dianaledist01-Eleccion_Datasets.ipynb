# %% [markdown]
# # **Data Science** 📈
#
# ## **Primera entrega** Elección de Datasets potenciales

# %% [markdown]
# ## Importación de pandas

# %%
import pandas as pd

# %% [markdown]
# ## Base de datos Nº1:
#
# En tanto me interesan los estudios de género ⚧️, el impacto de la desigualdad en nuestra sociedad y la brecha salarial en ámbitos profesionales 💰, esta base de datos muestra la cantidad de personas (divididas entre mujeres y varones) que ocupan roles jerenciales y directivos en distintas industrias a lo largo de Europa.
#
# 🛢️ Fuente: https://eige.europa.eu/gender-statistics/dgs/indicator/wmidm_bus_bus__wmid_comp_compbm

# %% [markdown]
# #### Conexión de la base de datos con Google Drive

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd '/conqtent/gdrive/MyDrive/data_science'
df= pd.read_csv('2023-11-10_gender_roles.csv',sep=',')
# Out:
# /content/gdrive/MyDrive/data_science

# %% [markdown]
# ### Ejecución del archivo .csv

# %%
df
# Out:
#            time _geo             geo  value                           UNIT  \
# 0       2012-B2   AT         Austria    0.0  Number of persons (headcount)
# 1       2013-B1   AT         Austria    0.0  Number of persons (headcount)
# 2       2013-B2   AT         Austria    0.0  Number of persons (headcount)
# 3       2014-B1   AT         Austria    0.0  Number of persons (headcount)
# 4       2014-B2   AT         Austria    0.0  Number of persons (headcount)
# ...         ...  ...             ...    ...                            ...
# 440911  2021-B1   UK  United Kingdom  100.0               Percent of total
# 440912  2021-B2   UK  United Kingdom  100.0               Percent of total
# 440913  2022-B1   UK  United Kingdom  100.0               Percent of total
# 440914  2022-B2   UK  United Kingdom  100.0               Percent of total
# 440915  2023-B1   UK  United Kingdom  100.0               Percent of total
#
# ...

# %% [markdown]
# ### Información de la base de datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440916 entries, 0 to 440915
# Data columns (total 14 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       440916 non-null  object
#  1   _geo       440916 non-null  object
#  2   geo        440916 non-null  object
#  3   value      435702 non-null  float64
#  4   UNIT       440916 non-null  object
#  5   _UNIT      440916 non-null  object
#  6   EGROUP     440916 non-null  object
#  7   _EGROUP    440916 non-null  object
#  8   POSITION   440916 non-null  object
#  9   _POSITION  440916 non-null  object
#  10  sex        440916 non-null  object
#  11  _sex       440916 non-null  object
#  12  NACE       440916 non-null  object
#  13  _NACE      440916 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 47.1+ MB

# %%
df.describe()
# Out:
#                value
# count  435702.000000
# mean       50.180760
# std       162.639902
# min         0.000000
# 25%         1.000000
# 50%        17.000000
# 75%        90.100000
# max      9661.000000

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Base de datos Nº2:
#
# Recientemente, he trabajado en un proyecto del mundo de la aeronáutica y tuve la inquietud de conocer las aeronaves que están en circulación y registradas en la actualidad, con datos de modelos, empresas y países de manufactura.
#
# 🛢️ Fuente: https://opensky-network.org/datasets/metadata/aircraftDatabase-2023-11.csv
#
# Nota: Este archivo parece interesante pero tiene varias columnas con valores NaN y otras tantas que no se muestran y que podrían ser más interesantes para el análisis. La función describe() da muchos más valores NaN que el dataframe en sí.
#
# #### Conexión de la base de datos con Google Drive

# %%
# %cd '/content/gdrive/MyDrive/data_science'
df2= pd.read_csv('aircraftDatabase-2023-11.csv',sep=',')
# Out:
# /content/gdrive/MyDrive/data_science

# %% [markdown]
# ### Ejecución del archivo .csv

# %%
df2
# Out:
#         icao24 registration manufacturericao  \
# 0          NaN          NaN              NaN
# 1       aa3487        N757F         RAYTHEON
# 2       a4fa61        N42MH            PIPER
# 3       a7a809       N5926K         ROCKWELL
# 4       391927       F-GGJH            ROBIN
# ...        ...          ...              ...
# 519995  c031da       C-FSWV           CESSNA
# 519996  a685af       N5193R            REIMS
# 519997  a2ef5c       N2889X           CESSNA
# 519998  c013da       C-FHNL          EMBRAER
# 519999  a7d3f7       N603SC              NaN
#
#                                       manufacturername  \
# 0                                                  NaN
# 1                            Raytheon Aircraft Company
# 2                                                Piper
# 3                                                  NaN
# 4                                                Robin
# ...                                                ...
# ...

# %% [markdown]
# ### Información de la base de datos

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520000 entries, 0 to 519999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   icao24               519999 non-null  object
#  1   registration         516529 non-null  object
#  2   manufacturericao     428796 non-null  object
#  3   manufacturername     438566 non-null  object
#  4   model                440425 non-null  object
#  5   typecode             479945 non-null  object
#  6   serialnumber         437120 non-null  object
#  7   linenumber           965 non-null     object
#  8   icaoaircrafttype     428780 non-null  object
#  9   operator             23683 non-null   object
#  10  operatorcallsign     40078 non-null   object
#  11  operatoricao         41393 non-null   object
#  12  operatoriata         8057 non-null    object
#  13  owner                435910 non-null  object
#  14  testreg              297 non-null     object
# ...

# %%
df2.describe()
# Out:
#        status  seatconfiguration
# count     0.0                0.0
# mean      NaN                NaN
# std       NaN                NaN
# min       NaN                NaN
# 25%       NaN                NaN
# 50%       NaN                NaN
# 75%       NaN                NaN
# max       NaN                NaN

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(df2)
# Out:
# <Axes: >

# %% [markdown]
# ## Base de datos Nº3:
#
# Esta database trata sobre estadísticas de educación alrededor del mundo.
#
# Fuente: https://datacatalog.worldbank.org/search/dataset/0038480/Education-Statistics
#
# Nota: Tiene muy baja cantidad de registros y muchos valores NaN.
#
# #### Conexión de la base de datos con Google Drive

# %%
# %cd '/content/gdrive/MyDrive/data_science'
df3= pd.read_csv('EdStatsCountry.csv',sep=',')
# Out:
# /content/gdrive/MyDrive/data_science

# %% [markdown]
# ### Ejecución del archivo .csv

# %%
df3
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            ABW         Aruba         Aruba                         Aruba
# 1            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 2            AGO        Angola        Angola   People's Republic of Angola
# 3            ALB       Albania       Albania           Republic of Albania
# 4            AND       Andorra       Andorra       Principality of Andorra
# ..           ...           ...           ...                           ...
# 236          XKX        Kosovo        Kosovo            Republic of Kosovo
# 237          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 238          ZAF  South Africa  South Africa      Republic of South Africa
# 239          ZMB        Zambia        Zambia            Republic of Zambia
# 240          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# ...

# %% [markdown]
# ### Información de la base de datos

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country Code                                       241 non-null    object
#  1   Short Name                                         241 non-null    object
#  2   Table Name                                         241 non-null    object
#  3   Long Name                                          241 non-null    object
#  4   2-alpha code                                       238 non-null    object
#  5   Currency Unit                                      215 non-null    object
#  6   Special Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
#  8   Income Group                                       214 non-null    object
# ...

# %%
df3.describe()
# Out:
#        National accounts reference year  Latest industrial data  \
# count                          32.00000              107.000000
# mean                         2001.53125             2008.102804
# std                             5.24856                2.616834
# min                          1987.00000             2000.000000
# 25%                          1996.75000             2007.500000
# 50%                          2002.00000             2009.000000
# 75%                          2005.00000             2010.000000
# max                          2012.00000             2010.000000
#
#        Latest trade data  Unnamed: 31
# count         185.000000          0.0
# mean         2010.994595          NaN
# std             2.569675          NaN
# min          1995.000000          NaN
# 25%          2011.000000          NaN
# 50%          2012.000000          NaN
# 75%          2012.000000          NaN
# max          2012.000000          NaN

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(df3)
# Out:
# <Axes: >

# %% [markdown]
# ## Base de datos Nº4:
#
# Conjunto de datos utilizados para estimar la brecha de género en el número de mujeres editoras y sus prácticas de edición en Wikipedia en español.
#
# Fuente: https://archive.ics.uci.edu/dataset/852/gender+gap+in+spanish+wp
#
#
# #### Conexión de la base de datos con Google Drive

# %%
# %cd '/content/gdrive/MyDrive/data_science'
df4= pd.read_csv('gender-gap-wikipedia.csv',sep=',')
# Out:
# /content/gdrive/MyDrive/data_science

# %% [markdown]
# ### Ejecución del archivo .csv

# %%
df4
# Out:
#       gender    C_api  C_man  E_NEds  E_Bpag        firstDay         lastDay  \
# 0          1     male      1       2       2  20170527205915  20170721044501
# 1          0  unknown      3       3       1  20110301072441  20170731213735
# 2          1     male      1       0       2  20060907204302  20140911191722
# 3          1     male      1       1       2  20121003144916  20121208180528
# 4          0  unknown      3       1       1  20070311125035  20141106121057
# ...      ...      ...    ...     ...     ...             ...             ...
# 4741       1     male      3       2       2  20120227100614  20170930073013
# 4742       0  unknown      3       3       1  20111108054659  20170906055641
# 4743       2  unknown      2       1       2  20120405102902  20170302073010
# 4744       2   female      3       3       2  20091014131349  20161112122730
# 4745       1  unknown      1       2       0  20050901045004  20151022222845
#
# ...

# %% [markdown]
# ### Información de la base de datos

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         4746 non-null   int64
#  1   C_api          4746 non-null   object
#  2   C_man          4746 non-null   int64
#  3   E_NEds         4746 non-null   int64
#  4   E_Bpag         4746 non-null   int64
#  5   firstDay       4746 non-null   int64
#  6   lastDay        4746 non-null   int64
#  7   NEds           4746 non-null   int64
#  8   NDays          4746 non-null   int64
#  9   NActDays       4746 non-null   int64
#  10  NPages         4746 non-null   int64
#  11  NPcreated      4746 non-null   int64
#  12  pagesWomen     4746 non-null   int64
#  13  wikiprojWomen  4746 non-null   int64
#  14  ns_user        4746 non-null   int64
#  15  ns_wikipedia   4746 non-null   int64
#  16  ns_talk        4746 non-null   int64
#  17  ns_userTalk    4746 non-null   int64
# ...

# %%
df4.describe()
# Out:
#             gender        C_man       E_NEds       E_Bpag      firstDay  \
# count  4746.000000  4746.000000  4746.000000  4746.000000  4.746000e+03
# mean      0.737042     2.082807     1.484197     1.646228  2.009942e+13
# std       0.585355     0.964978     1.099795     1.079263  3.516337e+10
# min       0.000000     1.000000     0.000000     0.000000  2.002011e+13
# 25%       0.000000     1.000000     1.000000     1.000000  2.007042e+13
# 50%       1.000000     3.000000     1.000000     2.000000  2.009121e+13
# 75%       1.000000     3.000000     2.000000     3.000000  2.013040e+13
# max       2.000000     3.000000     3.000000     3.000000  2.017093e+13
#
#             lastDay           NEds        NDays     NActDays        NPages  \
# count  4.746000e+03    4746.000000  4746.000000  4746.000000   4746.000000
# mean   2.015489e+13    2029.969448  2036.607880   183.162663    689.451960
# std    1.748104e+10    7793.300833  1336.119914   374.034481   3355.302483
# ...

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(df4)
# Out:
# <Axes: >
